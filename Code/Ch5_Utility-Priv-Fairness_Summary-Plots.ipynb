# %% [markdown]
# # Synthetic Datasets: Summary Plots of Utility, Privacy and Fairness Metrics
#
# Author: Ilse Harmers \
# Last modified: June 2, 2026

# %%
# Importing libraries.
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import matplotlib
params = {'axes.titlesize':'18',
          'xtick.labelsize':'15',
          'ytick.labelsize':'15',
          'font.size':'16',
          'legend.fontsize':'medium',
          'lines.linewidth':'2.0',
          'font.weight':'normal',
          'lines.markersize':'5',
          'text.latex.preamble': r'\usepackage{amsfonts}',
          'hatch.linewidth': '0.3',
          'hatch.color': "grey"
          }
matplotlib.rcParams.update(params)
plt.rcParams["mathtext.fontset"] = "cm"
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

def tf(data, counts):
    """This function transforms the given data to a percentile-representation when provided with a total 'count'."""
    return np.round(((np.array(data)/counts)*100), 1)

# %% [markdown]
# ## Summary Plots of Utility Metrics

# %%
# Summary plots of utility (AUROC and accuracy) improvements: Fair DP-GANs versus DP-CTGAN & DP-GAN. 
counts_util = 24

fdem_util = tf([4, 8], counts_util)
fdis_util = tf([5, 3], counts_util)
fdemdi_util = tf([5, 5], counts_util)
fcdem_util = tf([5, 5], counts_util)
fcdis_util = tf([3, 6], counts_util)
feqopp_util = tf([7, 5], counts_util)
fall_util = tf([5, 5], counts_util)
results_util = [fdem_util, fdis_util, fdemdi_util, fcdem_util, fcdis_util, feqopp_util, fall_util]

fdem_util_DPC = tf([4, 5], counts_util)
fdis_util_DPC = tf([5, 3], counts_util)
fdemdi_util_DPC = tf([4, 3], counts_util)
fcdem_util_DPC = tf([3, 4], counts_util)
fcdis_util_DPC = tf([5, 4], counts_util)
feqopp_util_DPC = tf([4, 3], counts_util)
fall_util_DPC = tf([5, 2], counts_util)
results_util_DPC = [fdem_util_DPC, fdis_util_DPC, fdemdi_util_DPC, fcdem_util_DPC, fcdis_util_DPC, feqopp_util_DPC, fall_util_DPC]

fdem_fdata = tf([4, 3, 5], counts_util)
fdis_fdata = tf([2, 2, 4], counts_util)
fdemdi_fdata = tf([3, 3, 4], counts_util)
fcdem_fdata = tf([2, 3, 5], counts_util)
fcdis_fdata = tf([4, 2, 3], counts_util)
feqopp_fdata = tf([4, 3, 5], counts_util)
fall_fdata = tf([4, 3, 3], counts_util)
results_fdata = [fdem_fdata, fdis_fdata, fdemdi_fdata, fcdem_fdata, fcdis_fdata, feqopp_fdata, fall_fdata]

fdem_fdata_DPC = tf([2, 3, 4], counts_util)
fdis_fdata_DPC = tf([1, 3, 4], counts_util)
fdemdi_fdata_DPC = tf([2, 2, 3], counts_util)
fcdem_fdata_DPC = tf([2, 2, 3], counts_util)
fcdis_fdata_DPC = tf([3, 3, 3], counts_util)
feqopp_fdata_DPC = tf([1, 3, 3], counts_util)
fall_fdata_DPC = tf([1, 3, 3], counts_util)
results_fdata_DPC = [fdem_fdata_DPC, fdis_fdata_DPC, fdemdi_fdata_DPC, fcdem_fdata_DPC, fcdis_fdata_DPC, feqopp_fdata_DPC, fall_fdata_DPC]

fig, ax = plt.subplots(1, 2, figsize = (16, 7.5))
ax[0].set_ylim(-0.74, 6.7)
ax[1].set_ylim(-0.74, 6.7)
ax[0].axvline(x = 50, color = "black", zorder = 0)
ax[1].axvline(x = 50, color = "black", zorder = 0)

rect1a = mpatches.Rectangle(xy = (-0.5, -1), width = 50, height = 10, color = 'red', alpha = 0.1, ec = 'red')
ax[0].add_patch(rect1a)
rect1b = mpatches.Rectangle(xy = (-0.5, -1), width = 50, height = 10, color = 'red', alpha = 0.1, ec = 'red')
ax[1].add_patch(rect1b)
rect2a = mpatches.Rectangle(xy = (50, -1), width = 50, height = 10, color = 'green', alpha = 0.1, ec = 'green')
ax[0].add_patch(rect2a)
rect2b = mpatches.Rectangle(xy = (50, -1), width = 50, height = 10, color = 'green', alpha = 0.1, ec = 'green')
ax[1].add_patch(rect2b)

positions = [0, 1, 2, 3, 4, 5, 6]
width = 0.4
colors = ["cyan", "gold", "thistle", "darkkhaki", "powderblue"]
labels = ["Accuracy", "AUROC", "Adult", "Bank", "Credit"]
hatches = [None, None, "/" , "--" , "x"]
legd_hatch = [None, None, "//" , "---" , "xx"]

for a in range(2):
    if a == 0:
        results = results_util
        results_DPC = results_util_DPC
    else:
        results = results_fdata
        results_DPC = results_fdata_DPC

    for r in range(len(results)):
        s1 = 0
        s2 = 0
        for c in range(len(results[r])):
            hbars = ax[a].barh([positions[r] - 0.55*width, positions[r] + 0.55*width], [results_DPC[r][c], results[r][c]], width, align = "center", 
                               left = [s1, s2], color = [colors[(c + a * 2)]]*2, hatch = [hatches[(c + a * 2)]]*2, 
                              )
            ax[a].bar_label(hbars, label_type = "center", fontsize = 12, color = "black")
            s1 += results_DPC[r][c]
            s2 += results[r][c]
            
    ax[a].set_xlabel("\%")
    ax[a].set_xlim([0, 100])
    ax[a].grid(True, axis = "x", linestyle = '--', alpha = 0.6)

ax[0].set_yticks(positions, labels = ["$Dem$", "$Dis$", "$Dem$ + $Dis$", "$\it{Clf.}$ $Dem$", "$\it{Clf.}$ $Dis$", "$\it{Clf.}$ $Eqopp$", 
                                      "$\it{Clf.}$ $All$"])
ax[1].set_yticks(positions, labels = [" "]*7)
ax[0].invert_yaxis()  # labels read top-to-bottom
ax[1].invert_yaxis()

fig.suptitle("Classifier Utility Improvements Across $\epsilon \in \{1, 2, 5, 8\}$: FairDPGANs Versus DP-CTGAN \& DP-GAN", y = 0.95)
plt.figlegend(handles = [mpatches.Patch(facecolor = colors[i], label = labels[i], hatch = legd_hatch[i]) for i in range(len(colors))], ncol = 6, 
              loc = "upper center", bbox_to_anchor = (0.5, 1.05))

plt.figtext(0.387, 0.819,  "vs. DP-CTGAN", size = 14)
plt.figtext(0.404, 0.771,  "vs. DP-GAN", size = 14)
plt.figtext(0.387, 0.718,  "vs. DP-CTGAN", size = 14)
plt.figtext(0.404, 0.670,  "vs. DP-GAN", size = 14)
plt.figtext(0.387, 0.617,  "vs. DP-CTGAN", size = 14)
plt.figtext(0.404, 0.569,  "vs. DP-GAN", size = 14)
plt.figtext(0.387, 0.511,  "vs. DP-CTGAN", size = 14)
plt.figtext(0.404, 0.463,  "vs. DP-GAN", size = 14)
plt.figtext(0.387, 0.409,  "vs. DP-CTGAN", size = 14)
plt.figtext(0.404, 0.359,  "vs. DP-GAN", size = 14)
plt.figtext(0.387, 0.300,  "vs. DP-CTGAN", size = 14)
plt.figtext(0.404, 0.251,  "vs. DP-GAN", size = 14)
plt.figtext(0.387, 0.195,  "vs. DP-CTGAN", size = 14)
plt.figtext(0.404, 0.147,  "vs. DP-GAN", size = 14)

plt.figtext(0.809, 0.819,  "vs. DP-CTGAN", size = 14)
plt.figtext(0.826, 0.771,  "vs. DP-GAN", size = 14)
plt.figtext(0.809, 0.718,  "vs. DP-CTGAN", size = 14)
plt.figtext(0.826, 0.670,  "vs. DP-GAN", size = 14)
plt.figtext(0.809, 0.617,  "vs. DP-CTGAN", size = 14)
plt.figtext(0.826, 0.569,  "vs. DP-GAN", size = 14)
plt.figtext(0.809, 0.511,  "vs. DP-CTGAN", size = 14)
plt.figtext(0.826, 0.463,  "vs. DP-GAN", size = 14)
plt.figtext(0.809, 0.409,  "vs. DP-CTGAN", size = 14)
plt.figtext(0.826, 0.359,  "vs. DP-GAN", size = 14)
plt.figtext(0.809, 0.300,  "vs. DP-CTGAN", size = 14)
plt.figtext(0.826, 0.251,  "vs. DP-GAN", size = 14)
plt.figtext(0.809, 0.195,  "vs. DP-CTGAN", size = 14)
plt.figtext(0.826, 0.147,  "vs. DP-GAN", size = 14)

plt.show()

# %% [markdown]
# ## Summary Plots of Privacy Metrics

# %%
# Summary plots of privacy (DCR and NNDR) improvements: Fair DP-GANs versus TabFairGAN & DP-GAN. 
counts_priv = 24

fdem_priv = tf([6, 6], counts_priv)
fdis_priv = tf([8, 5], counts_priv)
fdemdi_priv = tf([8, 6], counts_priv)
fcdem_priv = tf([7, 4], counts_priv)
fcdis_priv = tf([8, 7], counts_priv)
feqopp_priv = tf([4, 1], counts_priv)
fall_priv = tf([7, 6], counts_priv)
results_priv = [fdem_priv, fdis_priv, fdemdi_priv, fcdem_priv, fcdis_priv, feqopp_priv, fall_priv]

fdem_priv_TF = tf([11, 12], counts_priv)
fdis_priv_TF = tf([11, 12], counts_priv)
fdemdi_priv_TF = tf([12, 12], counts_priv)
fcdem_priv_TF = tf([11, 12], counts_priv)
fcdis_priv_TF = tf([11, 12], counts_priv)
feqopp_priv_TF = tf([12, 12], counts_priv)
fall_priv_TF = tf([12, 12], counts_priv)
results_priv_TF = [fdem_priv_TF, fdis_priv_TF, fdemdi_priv_TF, fcdem_priv_TF, fcdis_priv_TF, feqopp_priv_TF, fall_priv_TF]

fdem_fdata = tf([5, 4, 3], counts_priv)
fdis_fdata = tf([6, 3, 4], counts_priv)
fdemdi_fdata = tf([3, 7, 4], counts_priv)
fcdem_fdata = tf([3, 3, 5], counts_priv)
fcdis_fdata = tf([5, 6, 4], counts_priv)
feqopp_fdata = tf([1, 2, 2], counts_priv)
fall_fdata = tf([3, 7, 3], counts_priv)
results_fdata = [fdem_fdata, fdis_fdata, fdemdi_fdata, fcdem_fdata, fcdis_fdata, feqopp_fdata, fall_fdata]

fdem_fdata_TF = tf([8, 7, 8], counts_priv)
fdis_fdata_TF = tf([8, 7, 8], counts_priv)
fdemdi_fdata_TF = tf([8, 8, 8], counts_priv)
fcdem_fdata_TF = tf([8, 7, 8], counts_priv)
fcdis_fdata_TF = tf([8, 7, 8], counts_priv)
feqopp_fdata_TF = tf([8, 8, 8], counts_priv)
fall_fdata_TF = tf([8, 8, 8], counts_priv)
results_fdata_TF = [fdem_fdata_TF, fdis_fdata_TF, fdemdi_fdata_TF, fcdem_fdata_TF, fcdis_fdata_TF, feqopp_fdata_TF, fall_fdata_TF]

fig, ax = plt.subplots(1, 2, figsize = (16, 7.5))
ax[0].set_ylim(-0.74, 6.7)
ax[1].set_ylim(-0.74, 6.7)
ax[0].axvline(x = 50, color = "black", zorder = 0)
ax[1].axvline(x = 50, color = "black", zorder = 0)

rect1a = mpatches.Rectangle(xy = (-0.5, -1), width = 50, height = 10, color = 'red', alpha = 0.1, ec = 'red')
ax[0].add_patch(rect1a)
rect1b = mpatches.Rectangle(xy = (-0.5, -1), width = 50, height = 10, color = 'red', alpha = 0.1, ec = 'red')
ax[1].add_patch(rect1b)
rect2a = mpatches.Rectangle(xy = (50, -1), width = 50, height = 10, color = 'green', alpha = 0.1, ec = 'green')
ax[0].add_patch(rect2a)
rect2b = mpatches.Rectangle(xy = (50, -1), width = 50, height = 10, color = 'green', alpha = 0.1, ec = 'green')
ax[1].add_patch(rect2b)

positions = [0, 1, 2, 3, 4, 5, 6]
width = 0.4
colors = ["cornflowerblue", "fuchsia", "thistle", "darkkhaki", "powderblue"]
labels = ["DCR", "NNDR", "Adult", "Bank", "Credit"]
hatches = [None, None, "/" , "--" , "x"]
legd_hatch = [None, None, "//" , "---" , "xx"]

for a in range(2):
    if a == 0:
        results = results_priv
        results_TF = results_priv_TF
    else:
        results = results_fdata
        results_TF = results_fdata_TF

    for r in range(len(results)):
        s1 = 0
        s2 = 0
        for c in range(len(results[r])):
            hbars = ax[a].barh([positions[r] - 0.55*width, positions[r] + 0.55*width], [results_TF[r][c], results[r][c]], width, align = "center", 
                               left = [s1, s2], color = [colors[(c + a * 2)]]*2, hatch = [hatches[(c + a * 2)]]*2, 
                              )
            ax[a].bar_label(hbars, label_type = "center", fontsize = 12, color = "black")
            s1 += results_TF[r][c]
            s2 += results[r][c]
            
    ax[a].set_xlabel("\%")
    ax[a].set_xlim([0, 100])
    ax[a].grid(True, axis = "x", linestyle = '--', alpha = 0.6)

ax[0].set_yticks(positions, labels = ["$Dem$", "$Dis$", "$Dem$ + $Dis$", "$\it{Clf.}$ $Dem$", "$\it{Clf.}$ $Dis$", "$\it{Clf.}$ $Eqopp$", 
                                      "$\it{Clf.}$ $All$"])
ax[1].set_yticks(positions, labels = [" "]*7)
ax[0].invert_yaxis()  # labels read top-to-bottom
ax[1].invert_yaxis()

fig.suptitle("Privacy Improvements Across $\epsilon \in \{1, 2, 5, 8\}$: FairDPGANs Versus TabFairGAN \& DP-GAN", y = 0.95)
plt.figlegend(handles = [mpatches.Patch(facecolor = colors[i], label = labels[i], hatch = legd_hatch[i]) for i in range(len(colors))], ncol = 6, 
              loc = "upper center", bbox_to_anchor = (0.5, 1.05))

plt.figtext(0.404, 0.819,  "vs. TabFairGAN", size = 11)
plt.figtext(0.404, 0.771,  "vs. DP-GAN", size = 14)
plt.figtext(0.404, 0.718,  "vs. TabFairGAN", size = 11)
plt.figtext(0.404, 0.670,  "vs. DP-GAN", size = 14)
plt.figtext(0.404, 0.617,  "vs. TabFairGAN", size = 11)
plt.figtext(0.404, 0.569,  "vs. DP-GAN", size = 14)
plt.figtext(0.404, 0.511,  "vs. TabFairGAN", size = 11)
plt.figtext(0.404, 0.463,  "vs. DP-GAN", size = 14)
plt.figtext(0.404, 0.409,  "vs. TabFairGAN", size = 11)
plt.figtext(0.404, 0.359,  "vs. DP-GAN", size = 14)
plt.figtext(0.404, 0.300,  "vs. TabFairGAN", size = 11)
plt.figtext(0.404, 0.251,  "vs. DP-GAN", size = 14)
plt.figtext(0.404, 0.195,  "vs. TabFairGAN", size = 11)
plt.figtext(0.404, 0.147,  "vs. DP-GAN", size = 14)

plt.figtext(0.840, 0.819,  "vs. TabFairGAN", size = 9)
plt.figtext(0.826, 0.771,  "vs. DP-GAN", size = 14)
plt.figtext(0.840, 0.718,  "vs. TabFairGAN", size = 9)
plt.figtext(0.826, 0.670,  "vs. DP-GAN", size = 14)
plt.figtext(0.855, 0.617,  "vs. TabFair", size = 9)
plt.figtext(0.826, 0.569,  "vs. DP-GAN", size = 14)
plt.figtext(0.840, 0.511,  "vs. TabFairGAN", size = 9)
plt.figtext(0.826, 0.463,  "vs. DP-GAN", size = 14)
plt.figtext(0.840, 0.409,  "vs. TabFairGAN", size = 9)
plt.figtext(0.826, 0.359,  "vs. DP-GAN", size = 14)
plt.figtext(0.855, 0.300,  "vs. TabFair", size = 9)
plt.figtext(0.826, 0.251,  "vs. DP-GAN", size = 14)
plt.figtext(0.855, 0.195,  "vs. TabFair", size = 9)
plt.figtext(0.826, 0.147,  "vs. DP-GAN", size = 14)

plt.show()

# %% [markdown]
# ## Summary Plots of Fairness Metrics

# %% [markdown]
# ### Summary Plots of Dataset Group Fairness Metrics

# %%
# Summary plots of dataset group fairness (demographic parity and disparate impact) improvements: Fair DP-GANs versus TabFairGAN & DP-GAN.
counts_gp = 24

fdem_gpfair = tf([4, 6], counts_gp)
fdis_gpfair = tf([7, 7], counts_gp)
fdemdi_gpfair = tf([4, 3], counts_gp)
fcdem_gpfair = tf([6, 6], counts_gp)
fcdis_gpfair = tf([5, 6], counts_gp)
feqopp_gpfair = tf([3, 4], counts_gp)
fall_gpfair = tf([4, 3], counts_gp)
results_gpfair = [fdem_gpfair, fdis_gpfair, fdemdi_gpfair, fcdem_gpfair, fcdis_gpfair, feqopp_gpfair, fall_gpfair]

fdem_gpfair_TF = tf([5, 8], counts_gp)
fdis_gpfair_TF = tf([7, 6], counts_gp)
fdemdi_gpfair_TF = tf([3, 3], counts_gp)
fcdem_gpfair_TF = tf([4, 5], counts_gp)
fcdis_gpfair_TF = tf([7, 9], counts_gp)
feqopp_gpfair_TF = tf([7, 5], counts_gp)
fall_gpfair_TF = tf([5, 5], counts_gp)
results_gpfair_TF = [fdem_gpfair_TF, fdis_gpfair_TF, fdemdi_gpfair_TF, fcdem_gpfair_TF, fcdis_gpfair_TF, feqopp_gpfair_TF, fall_gpfair_TF]

fdem_fdata = tf([4, 4, 2], counts_gp)
fdis_fdata = tf([5, 6, 3], counts_gp)
fdemdi_fdata = tf([1, 5, 1], counts_gp)
fcdem_fdata = tf([2, 6, 4], counts_gp)
fcdis_fdata = tf([5, 1, 5], counts_gp)
feqopp_fdata = tf([2, 3, 2], counts_gp)
fall_fdata = tf([2, 3, 2], counts_gp)
results_fdata = [fdem_fdata, fdis_fdata, fdemdi_fdata, fcdem_fdata, fcdis_fdata, feqopp_fdata, fall_fdata]

fdem_fdata_TF = tf([5, 6, 2], counts_gp)
fdis_fdata_TF = tf([4, 7, 2], counts_gp)
fdemdi_fdata_TF = tf([0, 5, 1], counts_gp)
fcdem_fdata_TF = tf([0, 7, 2], counts_gp)
fcdis_fdata_TF = tf([6, 7, 3], counts_gp)
feqopp_fdata_TF = tf([2, 8, 2], counts_gp)
fall_fdata_TF = tf([3, 6, 1], counts_gp)
results_fdata_TF = [fdem_fdata_TF, fdis_fdata_TF, fdemdi_fdata_TF, fcdem_fdata_TF, fcdis_fdata_TF, feqopp_fdata_TF, fall_fdata_TF]

fig, ax = plt.subplots(1, 2, figsize = (16, 7.5))
ax[0].set_ylim(-0.74, 6.7)
ax[1].set_ylim(-0.74, 6.7)
ax[0].axvline(x = 50, color = "black", zorder = 0)
ax[1].axvline(x = 50, color = "black", zorder = 0)

rect1a = mpatches.Rectangle(xy = (-0.5, -1), width = 50, height = 10, color = 'red', alpha = 0.1, ec = 'red')
ax[0].add_patch(rect1a)
rect1b = mpatches.Rectangle(xy = (-0.5, -1), width = 50, height = 10, color = 'red', alpha = 0.1, ec = 'red')
ax[1].add_patch(rect1b)
rect2a = mpatches.Rectangle(xy = (50, -1), width = 50, height = 10, color = 'green', alpha = 0.1, ec = 'green')
ax[0].add_patch(rect2a)
rect2b = mpatches.Rectangle(xy = (50, -1), width = 50, height = 10, color = 'green', alpha = 0.1, ec = 'green')
ax[1].add_patch(rect2b)

positions = [0, 1, 2, 3, 4, 5, 6]
width = 0.4
colors = ["lightcoral", "greenyellow", "thistle", "darkkhaki", "powderblue"]
labels = ["Demographic parity", "Disparate impact", "Adult", "Bank", "Credit"]
hatches = [None, None, "/" , "--" , "x"]
legd_hatch = [None, None, "//" , "---" , "xx"]

for a in range(2):
    if a == 0:
        results = results_gpfair
        results_TF = results_gpfair_TF
    else:
        results = results_fdata
        results_TF = results_fdata_TF
    
    for r in range(len(results)):
        s1 = 0
        s2 = 0
        for c in range(len(results[r])):
            hbars = ax[a].barh([positions[r] - 0.55*width, positions[r] + 0.55*width], [results_TF[r][c], results[r][c]], width, align = "center", 
                               left = [s1, s2], color = [colors[(c + a * 2)]]*2, hatch = [hatches[(c + a * 2)]]*2, 
                              )
            if results_TF[r][c] == 0:
                labs = [" ", results[r][c]]
            else:
                labs = [results_TF[r][c], results[r][c]]
            ax[a].bar_label(hbars, labels = labs, label_type = "center", fontsize = 12, color = "black")
            s1 += results_TF[r][c]
            s2 += results[r][c]

    ax[a].set_xlabel("\%")
    ax[a].set_xlim([0, 100])
    ax[a].grid(True, axis = "x", linestyle = '--', alpha = 0.6)

ax[0].set_yticks(positions, labels = ["$Dem$", "$Dis$", "$Dem$ + $Dis$", "$\it{Clf.}$ $Dem$", "$\it{Clf.}$ $Dis$", "$\it{Clf.}$ $Eqopp$", 
                                      "$\it{Clf.}$ $All$"])
ax[1].set_yticks(positions, labels = [" "]*7)
ax[0].invert_yaxis()  # labels read top-to-bottom
ax[1].invert_yaxis()

fig.suptitle("Dataset Group Fairness Improvements Across $\epsilon \in \{1, 2, 5, 8\}$: FairDPGANs Versus TabFairGAN \& DP-GAN", y = 0.95)
plt.figlegend(handles = [mpatches.Patch(facecolor = colors[i], label = labels[i], hatch = legd_hatch[i]) for i in range(len(colors))], ncol = 6, 
              loc = "upper center", bbox_to_anchor = (0.5, 1.05))

plt.figtext(0.385, 0.819,  "vs. TabFairGAN", size = 14)
plt.figtext(0.404, 0.771,  "vs. DP-GAN", size = 14)
plt.figtext(0.385, 0.718,  "vs. TabFairGAN", size = 14)
plt.figtext(0.404, 0.670,  "vs. DP-GAN", size = 14)
plt.figtext(0.385, 0.617,  "vs. TabFairGAN", size = 14)
plt.figtext(0.404, 0.569,  "vs. DP-GAN", size = 14)
plt.figtext(0.385, 0.511,  "vs. TabFairGAN", size = 14)
plt.figtext(0.404, 0.463,  "vs. DP-GAN", size = 14)
plt.figtext(0.385, 0.409,  "vs. TabFairGAN", size = 14)
plt.figtext(0.404, 0.359,  "vs. DP-GAN", size = 14)
plt.figtext(0.385, 0.300,  "vs. TabFairGAN", size = 14)
plt.figtext(0.404, 0.251,  "vs. DP-GAN", size = 14)
plt.figtext(0.385, 0.195,  "vs. TabFairGAN", size = 14)
plt.figtext(0.404, 0.147,  "vs. DP-GAN", size = 14)

plt.figtext(0.807, 0.819,  "vs. TabFairGAN", size = 14)
plt.figtext(0.826, 0.771,  "vs. DP-GAN", size = 14)
plt.figtext(0.807, 0.718,  "vs. TabFairGAN", size = 14)
plt.figtext(0.826, 0.670,  "vs. DP-GAN", size = 14)
plt.figtext(0.807, 0.617,  "vs. TabFairGAN", size = 14)
plt.figtext(0.826, 0.569,  "vs. DP-GAN", size = 14)
plt.figtext(0.807, 0.511,  "vs. TabFairGAN", size = 14)
plt.figtext(0.826, 0.463,  "vs. DP-GAN", size = 14)
plt.figtext(0.807, 0.409,  "vs. TabFairGAN", size = 14)
plt.figtext(0.826, 0.359,  "vs. DP-GAN", size = 14)
plt.figtext(0.807, 0.300,  "vs. TabFairGAN", size = 14)
plt.figtext(0.826, 0.251,  "vs. DP-GAN", size = 14)
plt.figtext(0.807, 0.195,  "vs. TabFairGAN", size = 14)
plt.figtext(0.826, 0.147,  "vs. DP-GAN", size = 14)

plt.show()

# %% [markdown]
# ### Summary Plots of Classifier Group Fairness Metrics

# %%
# Summary plots of classifier group fairness (demographic parity, disparate impact and equal opportunity) improvements: Fair DP-GANs versus TabFairGAN 
# & DP-GAN.
counts_gp = 36

fdem_gpfair = tf([6, 7, 6], counts_gp)
fdis_gpfair = tf([8, 10, 9], counts_gp)
fdemdi_gpfair = tf([7, 7, 6], counts_gp)
fcdem_gpfair = tf([5, 8, 6], counts_gp)
fcdis_gpfair = tf([8, 9, 5], counts_gp)
feqopp_gpfair = tf([7, 8, 7], counts_gp)
fall_gpfair = tf([7, 8, 7], counts_gp)
results_gpfair = [fdem_gpfair, fdis_gpfair, fdemdi_gpfair, fcdem_gpfair, fcdis_gpfair, feqopp_gpfair, fall_gpfair]

fdem_gpfair_TF = tf([3, 7, 6], counts_gp)
fdis_gpfair_TF = tf([8, 8, 9], counts_gp)
fdemdi_gpfair_TF = tf([8, 6, 6], counts_gp)
fcdem_gpfair_TF = tf([6, 5, 8], counts_gp)
fcdis_gpfair_TF = tf([6, 8, 3], counts_gp)
feqopp_gpfair_TF = tf([6, 6, 6], counts_gp)
fall_gpfair_TF = tf([7, 7, 6], counts_gp)
results_gpfair_TF = [fdem_gpfair_TF, fdis_gpfair_TF, fdemdi_gpfair_TF, fcdem_gpfair_TF, fcdis_gpfair_TF, feqopp_gpfair_TF, fall_gpfair_TF]

fdem_fdata = tf([2, 10, 7], counts_gp)
fdis_fdata = tf([9, 10, 8], counts_gp)
fdemdi_fdata = tf([6, 7, 7], counts_gp)
fcdem_fdata = tf([2, 9, 8], counts_gp)
fcdis_fdata = tf([6, 8, 8], counts_gp)
feqopp_fdata = tf([7, 7, 8], counts_gp)
fall_fdata = tf([6, 8, 8], counts_gp)
results_fdata = [fdem_fdata, fdis_fdata, fdemdi_fdata, fcdem_fdata, fcdis_fdata, feqopp_fdata, fall_fdata]

fdem_fdata_TF = tf([3, 9, 4], counts_gp)
fdis_fdata_TF = tf([9, 9, 7], counts_gp)
fdemdi_fdata_TF = tf([7, 6, 7], counts_gp)
fcdem_fdata_TF = tf([5, 7, 7], counts_gp)
fcdis_fdata_TF = tf([7, 6, 4], counts_gp)
feqopp_fdata_TF = tf([6, 8, 4], counts_gp)
fall_fdata_TF = tf([8, 8, 4], counts_gp)
results_fdata_TF = [fdem_fdata_TF, fdis_fdata_TF, fdemdi_fdata_TF, fcdem_fdata_TF, fcdis_fdata_TF, feqopp_fdata_TF, fall_fdata_TF]

fig, ax = plt.subplots(1, 2, figsize = (16, 7.5))
ax[0].set_ylim(-0.74, 6.7)
ax[1].set_ylim(-0.74, 6.7)
ax[0].axvline(x = 50, color = "black", zorder = 0)
ax[1].axvline(x = 50, color = "black", zorder = 0)

rect1a = mpatches.Rectangle(xy = (-0.5, -1), width = 50, height = 10, color = 'red', alpha = 0.1, ec = 'red')
ax[0].add_patch(rect1a)
rect1b = mpatches.Rectangle(xy = (-0.5, -1), width = 50, height = 10, color = 'red', alpha = 0.1, ec = 'red')
ax[1].add_patch(rect1b)
rect2a = mpatches.Rectangle(xy = (50, -1), width = 50, height = 10, color = 'green', alpha = 0.1, ec = 'green')
ax[0].add_patch(rect2a)
rect2b = mpatches.Rectangle(xy = (50, -1), width = 50, height = 10, color = 'green', alpha = 0.1, ec = 'green')
ax[1].add_patch(rect2b)

positions = [0, 1, 2, 3, 4, 5, 6]
width = 0.4
colors = ["lightcoral", "greenyellow", "mediumpurple", "thistle", "darkkhaki", "powderblue"]
labels = ["Demographic parity", "Disparate impact", "Equal opportunity", "Adult", "Bank", "Credit"]
hatches = [None, None, None, "/" , "--" , "x"]
legd_hatch = [None, None, None, "//" , "---" , "xx"]

for a in range(2):
    if a == 0:
        results = results_gpfair
        results_TF = results_gpfair_TF
    else:
        results = results_fdata
        results_TF = results_fdata_TF
    
    for r in range(len(results)):
        s1 = 0
        s2 = 0
        for c in range(len(results[r])):
            hbars = ax[a].barh([positions[r] - 0.55*width, positions[r] + 0.55*width], [results_TF[r][c], results[r][c]], width, align = "center", 
                               left = [s1, s2], color = [colors[(c + a * 3)]]*2, hatch = [hatches[(c + a * 3)]]*2, 
                              )
            ax[a].bar_label(hbars, label_type = "center", fontsize = 15, color = "black")
            s1 += results_TF[r][c]
            s2 += results[r][c]

    ax[a].set_xlabel("\%")
    ax[a].set_xlim([0, 100])
    ax[a].grid(True, axis = "x", linestyle = '--', alpha = 0.6)

ax[0].set_yticks(positions, labels = ["$Dem$", "$Dis$", "$Dem$ + $Dis$", "$\it{Clf.}$ $Dem$", "$\it{Clf.}$ $Dis$", "$\it{Clf.}$ $Eqopp$", 
                                      "$\it{Clf.}$ $All$"])
ax[1].set_yticks(positions, labels = [" "]*7)
ax[0].invert_yaxis()  # labels read top-to-bottom
ax[1].invert_yaxis()

fig.suptitle("Classifier Group Fairness Improvements Across $\epsilon \in \{1, 2, 5, 8\}$: FairDPGANs Versus TabFairGAN \& DP-GAN", y = 0.95)
plt.figlegend(handles = [mpatches.Patch(facecolor = colors[i], label = labels[i], hatch = legd_hatch[i]) for i in range(len(colors))], ncol = 6, 
              loc = "upper center", bbox_to_anchor = (0.48, 1.05))

plt.figtext(0.385, 0.819,  "vs. TabFairGAN", size = 14)
plt.figtext(0.404, 0.771,  "vs. DP-GAN", size = 14)
plt.figtext(0.385, 0.718,  "vs. TabFairGAN", size = 14)
plt.figtext(0.404, 0.670,  "vs. DP-GAN", size = 14)
plt.figtext(0.385, 0.617,  "vs. TabFairGAN", size = 14)
plt.figtext(0.404, 0.569,  "vs. DP-GAN", size = 14)
plt.figtext(0.385, 0.511,  "vs. TabFairGAN", size = 14)
plt.figtext(0.404, 0.463,  "vs. DP-GAN", size = 14)
plt.figtext(0.385, 0.409,  "vs. TabFairGAN", size = 14)
plt.figtext(0.404, 0.359,  "vs. DP-GAN", size = 14)
plt.figtext(0.385, 0.300,  "vs. TabFairGAN", size = 14)
plt.figtext(0.404, 0.251,  "vs. DP-GAN", size = 14)
plt.figtext(0.385, 0.195,  "vs. TabFairGAN", size = 14)
plt.figtext(0.404, 0.147,  "vs. DP-GAN", size = 14)

plt.figtext(0.807, 0.819,  "vs. TabFairGAN", size = 14)
plt.figtext(0.826, 0.771,  "vs. DP-GAN", size = 14)
plt.figtext(0.807, 0.718,  "vs. TabFairGAN", size = 14)
plt.figtext(0.826, 0.670,  "vs. DP-GAN", size = 14)
plt.figtext(0.807, 0.617,  "vs. TabFairGAN", size = 14)
plt.figtext(0.826, 0.569,  "vs. DP-GAN", size = 14)
plt.figtext(0.807, 0.511,  "vs. TabFairGAN", size = 14)
plt.figtext(0.826, 0.463,  "vs. DP-GAN", size = 14)
plt.figtext(0.807, 0.409,  "vs. TabFairGAN", size = 14)
plt.figtext(0.826, 0.359,  "vs. DP-GAN", size = 14)
plt.figtext(0.807, 0.300,  "vs. TabFairGAN", size = 14)
plt.figtext(0.826, 0.251,  "vs. DP-GAN", size = 14)
plt.figtext(0.807, 0.195,  "vs. TabFairGAN", size = 14)
plt.figtext(0.826, 0.147,  "vs. DP-GAN", size = 14)

plt.show()

# %% [markdown]
# ### Summary Plots of Individual Fairness Metrics

# %%
# Summary plots of individual fairness (similarity fairness and neighborhood consistency fairness) improvements: Fair DP-GANs versus TabFairGAN 
# & DP-GAN.
counts_if = 24

fdem_iffair = tf([5, 2], counts_if)
fdis_iffair = tf([8, 8], counts_if)
fdemdi_iffair = tf([7, 7], counts_if)
fcdem_iffair = tf([7, 6], counts_if)
fcdis_iffair = tf([4, 3], counts_if)
feqopp_iffair = tf([6, 6], counts_if)
fall_iffair = tf([5, 6], counts_if)
results_iffair = [fdem_iffair, fdis_iffair, fdemdi_iffair, fcdem_iffair, fcdis_iffair, feqopp_iffair, fall_iffair]

fdem_iffair_TF = tf([11, 8], counts_if)
fdis_iffair_TF = tf([12, 11], counts_if)
fdemdi_iffair_TF = tf([11, 10], counts_if)
fcdem_iffair_TF = tf([9, 8], counts_if)
fcdis_iffair_TF = tf([9, 9], counts_if)
feqopp_iffair_TF = tf([11, 9], counts_if)
fall_iffair_TF = tf([11, 10], counts_if)
results_iffair_TF = [fdem_iffair_TF, fdis_iffair_TF, fdemdi_iffair_TF, fcdem_iffair_TF, fcdis_iffair_TF, feqopp_iffair_TF, fall_iffair_TF]

fdem_fdata = tf([3, 3, 1], counts_if)
fdis_fdata = tf([6, 6, 4], counts_if)
fdemdi_fdata = tf([5, 6, 3], counts_if)
fcdem_fdata = tf([4, 6, 3], counts_if)
fcdis_fdata = tf([2, 4, 1], counts_if)
feqopp_fdata = tf([4, 5, 3], counts_if)
fall_fdata = tf([4, 4, 3], counts_if)
results_fdata = [fdem_fdata, fdis_fdata, fdemdi_fdata, fcdem_fdata, fcdis_fdata, feqopp_fdata, fall_fdata]

fdem_fdata_TF = tf([6, 6, 7], counts_if)
fdis_fdata_TF = tf([8, 7, 8], counts_if)
fdemdi_fdata_TF = tf([7, 8, 6], counts_if)
fcdem_fdata_TF = tf([6, 6, 5], counts_if)
fcdis_fdata_TF = tf([4, 7, 7], counts_if)
feqopp_fdata_TF = tf([6, 7, 7], counts_if)
fall_fdata_TF = tf([8, 7, 6], counts_if)
results_fdata_TF = [fdem_fdata_TF, fdis_fdata_TF, fdemdi_fdata_TF, fcdem_fdata_TF, fcdis_fdata_TF, feqopp_fdata_TF, fall_fdata_TF]

fig, ax = plt.subplots(1, 2, figsize = (16, 7.5))
ax[0].set_ylim(-0.74, 6.7)
ax[1].set_ylim(-0.74, 6.7)
ax[0].axvline(x = 50, color = "black", zorder = 0)
ax[1].axvline(x = 50, color = "black", zorder = 0)

rect1a = mpatches.Rectangle(xy = (-0.5, -1), width = 50, height = 10, color = 'red', alpha = 0.1, ec = 'red')
ax[0].add_patch(rect1a)
rect1b = mpatches.Rectangle(xy = (-0.5, -1), width = 50, height = 10, color = 'red', alpha = 0.1, ec = 'red')
ax[1].add_patch(rect1b)
rect2a = mpatches.Rectangle(xy = (50, -1), width = 50, height = 10, color = 'green', alpha = 0.1, ec = 'green')
ax[0].add_patch(rect2a)
rect2b = mpatches.Rectangle(xy = (50, -1), width = 50, height = 10, color = 'green', alpha = 0.1, ec = 'green')
ax[1].add_patch(rect2b)

positions = [0, 1, 2, 3, 4, 5, 6]
width = 0.4
colors = ["limegreen", "peru", "thistle", "darkkhaki", "powderblue"]
labels = ["ASF", "ANCF", "Adult", "Bank", "Credit"]
hatches = [None, None, "/" , "--" , "x"]
legd_hatch = [None, None, "//" , "---" , "xx"]

for a in range(2):
    if a == 0:
        results = results_iffair
        results_TF = results_iffair_TF
    else:
        results = results_fdata
        results_TF = results_fdata_TF
    
    for r in range(len(results)):
        s1 = 0
        s2 = 0
        for c in range(len(results[r])):
            hbars = ax[a].barh([positions[r] - 0.55*width, positions[r] + 0.55*width], [results_TF[r][c], results[r][c]], width, align = "center", 
                               left = [s1, s2], color = [colors[(c + a * 2)]]*2, hatch = [hatches[(c + a * 2)]]*2, 
                              )
            ax[a].bar_label(hbars, label_type = "center", fontsize = 15, color = "black")
            s1 += results_TF[r][c]
            s2 += results[r][c]

    ax[a].set_xlabel("\%")
    ax[a].set_xlim([0, 100])
    ax[a].grid(True, axis = "x", linestyle = '--', alpha = 0.6)

ax[0].set_yticks(positions, labels = ["$Dem$", "$Dis$", "$Dem$ + $Dis$", "$\it{Clf.}$ $Dem$", "$\it{Clf.}$ $Dis$", "$\it{Clf.}$ $Eqopp$", 
                                      "$\it{Clf.}$ $All$"])
ax[1].set_yticks(positions, labels = [" "]*7)
ax[0].invert_yaxis()  # labels read top-to-bottom
ax[1].invert_yaxis()

fig.suptitle("Individual Fairness Improvements Across $\epsilon \in \{1, 2, 5, 8\}$: FairDPGANs Versus TabFairGAN \& DP-GAN", y = 0.95)
plt.figlegend(handles = [mpatches.Patch(facecolor = colors[i], label = labels[i], hatch = legd_hatch[i]) for i in range(len(colors))], ncol = 6, 
              loc = "upper center", bbox_to_anchor = (0.5, 1.05))

plt.figtext(0.385, 0.819,  "vs. TabFairGAN", size = 14)
plt.figtext(0.404, 0.771,  "vs. DP-GAN", size = 14)
plt.figtext(0.402, 0.718,  "vs. TabFairGAN", size = 12)
plt.figtext(0.404, 0.670,  "vs. DP-GAN", size = 14)
plt.figtext(0.385, 0.617,  "vs. TabFairGAN", size = 14)
plt.figtext(0.404, 0.569,  "vs. DP-GAN", size = 14)
plt.figtext(0.385, 0.511,  "vs. TabFairGAN", size = 14)
plt.figtext(0.404, 0.463,  "vs. DP-GAN", size = 14)
plt.figtext(0.385, 0.409,  "vs. TabFairGAN", size = 14)
plt.figtext(0.404, 0.359,  "vs. DP-GAN", size = 14)
plt.figtext(0.385, 0.300,  "vs. TabFairGAN", size = 14)
plt.figtext(0.404, 0.251,  "vs. DP-GAN", size = 14)
plt.figtext(0.385, 0.195,  "vs. TabFairGAN", size = 14)
plt.figtext(0.404, 0.147,  "vs. DP-GAN", size = 14)

plt.figtext(0.807, 0.819,  "vs. TabFairGAN", size = 14)
plt.figtext(0.826, 0.771,  "vs. DP-GAN", size = 14)
plt.figtext(0.840, 0.718,  "vs. TabFairGAN", size = 9)
plt.figtext(0.826, 0.670,  "vs. DP-GAN", size = 14)
plt.figtext(0.824, 0.617,  "vs. TabFairGAN", size = 12)
plt.figtext(0.826, 0.569,  "vs. DP-GAN", size = 14)
plt.figtext(0.807, 0.511,  "vs. TabFairGAN", size = 14)
plt.figtext(0.826, 0.463,  "vs. DP-GAN", size = 14)
plt.figtext(0.807, 0.409,  "vs. TabFairGAN", size = 14)
plt.figtext(0.826, 0.359,  "vs. DP-GAN", size = 14)
plt.figtext(0.807, 0.300,  "vs. TabFairGAN", size = 14)
plt.figtext(0.826, 0.251,  "vs. DP-GAN", size = 14)
plt.figtext(0.824, 0.195,  "vs. TabFairGAN", size = 12)
plt.figtext(0.826, 0.147,  "vs. DP-GAN", size = 14)

plt.show()
